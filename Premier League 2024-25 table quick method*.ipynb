# %%
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt

from plottable import ColumnDefinition, Table
from plottable.cmap import normed_cmap
from plottable.plots import image

# %%
df=pd.read_html('https://fbref.com/en/comps/9/Premier-League-Stats', attrs={"id":"results2024-202591_overall"})[0]

# %%
df.head()
# Out:
#    Rk            Squad  MP   W   D   L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0   1        Liverpool  36  25   8   3  83  37  46   83    2.31  77.9  34.4
# 1   2          Arsenal  36  18  14   4  66  33  33   68    1.89  56.7  32.4
# 2   3    Newcastle Utd  36  20   6  10  68  45  23   66    1.83  61.1  43.7
# 3   4  Manchester City  36  19   8   9  67  43  24   65    1.81  63.6  45.3
# 4   5          Chelsea  36  18   9   9  62  43  19   63    1.75  65.9  45.8
#
#     xGD  xGD/90     Last 5  Attendance      Top Team Scorer      Goalkeeper  \
# 0  43.6    1.21  W W W L D       60321   Mohamed Salah - 28         Alisson
# 1  24.3    0.68  D W D L D       60256      Kai Havertz - 9      David Raya
# 2  17.3    0.48  W L W D W       52185  Alexander Isak - 23       Nick Pope
# 3  18.3    0.51  W W W W D       52741  Erling Haaland - 21         Ederson
# 4  20.1    0.56  D W W W L       39652     Cole Palmer - 15  Robert Sánchez
#
#    Notes
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
df['Badge']=df['Squad'].apply(
    lambda x: f"/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/team_logos/{x.lower()}_logo.png"
)

# %%
df['Badge'].tolist()
# Out:
# ['/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/team_logos/liverpool_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/team_logos/arsenal_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/team_logos/newcastle utd_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/team_logos/manchester city_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/team_logos/chelsea_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/team_logos/aston villa_logo.png',
#  "/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/team_logos/nott'ham forest_logo.png",
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/team_logos/brentford_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/team_logos/brighton_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/team_logos/bournemouth_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/team_logos/fulham_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/team_logos/crystal palace_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/team_logos/everton_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/team_logos/wolves_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/team_logos/west ham_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/team_logos/manchester utd_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/team_logos/tottenham_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/team_logos/ipswich town_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/team_logos/leicester city_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/team_logos/southampton_logo.png']

# %%
df.columns
# Out:
# Index(['Rk', 'Squad', 'MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Pts/MP',
#        'xG', 'xGA', 'xGD', 'xGD/90', 'Last 5', 'Attendance', 'Top Team Scorer',
#        'Goalkeeper', 'Notes', 'Badge'],
#       dtype='object')

# %%
#Some data cleaning
df=df[['Rk','Badge','Squad','MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Pts/MP',
       'xG', 'xGA', 'xGD', 'xGD/90']]

# %%
df
# Out:
#     Rk                                              Badge            Squad  \
# 0    1  /Users/siphuvuyomngxunyeni/Downloads/Football ...        Liverpool
# 1    2  /Users/siphuvuyomngxunyeni/Downloads/Football ...          Arsenal
# 2    3  /Users/siphuvuyomngxunyeni/Downloads/Football ...    Newcastle Utd
# 3    4  /Users/siphuvuyomngxunyeni/Downloads/Football ...  Manchester City
# 4    5  /Users/siphuvuyomngxunyeni/Downloads/Football ...          Chelsea
# 5    6  /Users/siphuvuyomngxunyeni/Downloads/Football ...      Aston Villa
# 6    7  /Users/siphuvuyomngxunyeni/Downloads/Football ...  Nott'ham Forest
# 7    8  /Users/siphuvuyomngxunyeni/Downloads/Football ...        Brentford
# 8    9  /Users/siphuvuyomngxunyeni/Downloads/Football ...         Brighton
# 9   10  /Users/siphuvuyomngxunyeni/Downloads/Football ...      Bournemouth
# 10  11  /Users/siphuvuyomngxunyeni/Downloads/Football ...           Fulham
# 11  12  /Users/siphuvuyomngxunyeni/Downloads/Football ...   Crystal Palace
# 12  13  /Users/siphuvuyomngxunyeni/Downloads/Football ...          Everton
# 13  14  /Users/siphuvuyomngxunyeni/Downloads/Football ...           Wolves
# 14  15  /Users/siphuvuyomngxunyeni/Downloads/Football ...         West Ham
# 15  16  /Users/siphuvuyomngxunyeni/Downloads/Football ...   Manchester Utd
# 16  17  /Users/siphuvuyomngxunyeni/Downloads/Football ...        Tottenham
# 17  18  /Users/siphuvuyomngxunyeni/Downloads/Football ...     Ipswich Town
# 18  19  /Users/siphuvuyomngxunyeni/Downloads/Football ...   Leicester City
# 19  20  /Users/siphuvuyomngxunyeni/Downloads/Football ...      Southampton
#
#     MP   W   D   L  GF  GA  GD  Pts  Pts/MP    xG   xGA   xGD  xGD/90
# 0   36  25   8   3  83  37  46   83    2.31  77.9  34.4  43.6    1.21
# 1   36  18  14   4  66  33  33   68    1.89  56.7  32.4  24.3    0.68
# 2   36  20   6  10  68  45  23   66    1.83  61.1  43.7  17.3    0.48
# 3   36  19   8   9  67  43  24   65    1.81  63.6  45.3  18.3    0.51
# 4   36  18   9   9  62  43  19   63    1.75  65.9  45.8  20.1    0.56
# 5   36  18   9   9  56  49   7   63    1.75  54.3  46.7   7.6    0.21
# 6   36  18   8  10  56  44  12   62    1.72  42.4  46.7  -4.4   -0.12
# 7   36  16   7  13  63  53  10   55    1.53  55.0  53.4   1.6    0.05
# 8   36  14  13   9  59  56   3   55    1.53  54.3  50.3   4.0    0.11
# 9   36  14  11  11  55  43  12   53    1.47  61.3  46.7  14.6    0.41
# 10  36  14   9  13  51  50   1   51    1.42  46.8  41.7   5.1    0.14
# 11  36  12  13  11  46  48  -2   49    1.36  57.0  45.6  11.4    0.32
# 12  36   9  15  12  39  44  -5   42    1.17  37.9  43.9  -5.9   -0.16
# 13  36  12   5  19  51  64 -13   41    1.14  41.3  55.0 -13.8   -0.38
# 14  36  10  10  16  42  59 -17   40    1.11  44.6  57.1 -12.5   -0.35
# 15  36  10   9  17  42  53 -11   39    1.08  49.4  52.4  -3.0   -0.08
# 16  36  11   5  20  63  59   4   38    1.06  56.2  59.7  -3.5   -0.10
# 17  36   4  10  22  35  77 -42   22    0.61  32.2  70.8 -38.6   -1.07
# 18  36   5   7  24  31  78 -47   22    0.61  31.6  68.9 -37.3   -1.04
# 19  36   2   6  28  25  82 -57   12    0.33  30.8  79.8 -49.0   -1.36

# %%
# Set up the colors
# Used Coolors to get the color hex codes: https://coolors.co/?ref=65623355a0453d000b8a2708
bg_color = "#FFFFFF" # I usually just like to do a white background
text_color = "#000000" # With black text

row_colors = {
"even": "#E2E2E1",
"odd": "#B3B0B0",
}

plt.rcParams["text.color"] = text_color
plt.rcParams["font.family"] = "monospace"

# %%
col_defs=[
    ColumnDefinition(
        name="Rk",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="Badge",
        textprops={"ha": "right", "va": "center", 'color': bg_color},
        width=0.5,
        plot_fn=image,
    ),
    ColumnDefinition(
        name="Squad",
        textprops={"ha": "left"},
        width=1.75,
    ),
    ColumnDefinition(
        name="MP",
        group="Matches Played",
        textprops={"ha": "center", "weight": "bold"},
        width=0.5,
    ),
    ColumnDefinition(
        name="W",
        group="Matches Played",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="D",
        group="Matches Played",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="L",
        group="Matches Played",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="GF",
        group="Goals",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="GA",
        group="Goals",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="GD",
        group="Goals",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="Pts",
        group="Points",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="Pts/MP",
        group="Points",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="xG",
        group="Expected Goals",
        textprops={"ha": "center", "color": "#000000", "weight": "bold", "bbox": {"boxstyle": "circle", "pad": 0.35}},
        cmap=normed_cmap(df["xG"], cmap=matplotlib.cm.PiYG, num_stds=2)
    ),
    ColumnDefinition(
        name="xGA",
        group="Expected Goals",
        textprops={"ha": "center", "color": "#000000", "weight": "bold", "bbox": {"boxstyle": "circle", "pad": 0.35}},
        cmap=normed_cmap(df["xGA"], cmap=matplotlib.cm.PiYG_r, num_stds=2)
    ),
    ColumnDefinition(
        name="xGD",
        group="Expected Goals",
        textprops={"ha": "center", "color": "#000000", "weight": "bold", "bbox": {"boxstyle": "circle", "pad": 0.35}},
        cmap=normed_cmap(df["xGD"], cmap=matplotlib.cm.PiYG, num_stds=2)
    ),
    ColumnDefinition(
        name="xGD/90",
        textprops={"ha": "center", "color": "#000000", "weight": "bold", "bbox": {"boxstyle": "circle", "pad": 0.35}},
        cmap=normed_cmap(df["xGD/90"], cmap=matplotlib.cm.PiYG, num_stds=2)
),
    ColumnDefinition(
        name="Top Scorer Image",
        textprops={"ha":"center", 'color': bg_color},
        plot_fn=image,
        width=0.75,
),
    ColumnDefinition(
        name="Top Team Scorer",
        textprops={"ha":"center"},
        width=1.75,
),
]

# %%
from matplotlib.lines import Line2D
fig, ax = plt.subplots(figsize=(20, 22))
fig.set_facecolor(bg_color)
ax.set_facecolor(bg_color)
table = Table(
    df,
    column_definitions=col_defs,
    index_col="Rk",
    row_dividers=True,
    row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    footer_divider=True,
    textprops={"fontsize": 14},
    col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    column_border_kw={"linewidth": .5, "linestyle": "-"},
    ax=ax,
).autoset_fontcolors(colnames=["xG", "xGA", "xGD"])

#League badge
club_image=Image.open('/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Premier_League_Logo.png')
imagebox=OffsetImage(club_image, zoom=0.65)
ab=AnnotationBbox(imagebox, (0.05,0.99), frameon=True, xycoords='axes fraction')
ax.add_artist(ab)

#Add title at the top
fig.suptitle('2024-25 Premier League Stats', fontsize=28, color=text_color, weight='bold', y=0.9)

plt.savefig("/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Premier League 2024-25 Table using quick method.png",
    facecolor= ax.get_facecolor(),
    dpi=200,
    bbox_inches="tight",
)
fig.show()
# Out:
# /var/folders/tc/b844__mx5sl6dq_8zjb208yh0000gn/T/ipykernel_42603/2271662864.py:32: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
