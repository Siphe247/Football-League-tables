# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

from plottable import ColumnDefinition, Table
from plottable.cmap import normed_cmap
from plottable.plots import image

# %%
df=pd.read_html('https://fbref.com/en/comps/12/La-Liga-Stats', attrs={"id": "results2024-2025121_overall"})[0]

# %%
df
# Out:
#     Rk            Squad  MP   W   D   L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0    1        Barcelona  35  26   4   5  95  36  59   82    2.34  86.0  37.6
# 1    2      Real Madrid  35  23   6   6  72  37  35   75    2.14  68.1  40.9
# 2    3  Atlético Madrid  35  20  10   5  60  27  33   70    2.00  55.8  31.9
# 3    4    Athletic Club  35  17  13   5  51  26  25   64    1.83  49.5  33.4
# 4    5       Villarreal  35  17  10   8  61  47  14   61    1.74  60.4  40.5
# 5    6            Betis  35  16  10   9  53  43  10   58    1.66  51.6  43.9
# 6    7       Celta Vigo  36  15   7  14  56  54   2   52    1.44  50.3  41.7
# 7    8   Rayo Vallecano  35  12  11  12  37  42  -5   47    1.34  40.9  44.8
# 8    9         Mallorca  35  13   8  14  33  40  -7   47    1.34  37.2  40.4
# 9   10          Osasuna  35  10  15  10  43  51  -8   45    1.29  40.6  49.6
# 10  11         Valencia  35  11  12  12  43  51  -8   45    1.29  41.2  48.1
# 11  12    Real Sociedad  36  12   7  17  32  42 -10   43    1.19  39.6  39.1
# 12  13           Girona  36  11   8  17  42  53 -11   41    1.14  40.1  45.7
# 13  14          Sevilla  36  10  11  15  40  49  -9   41    1.14  40.5  44.3
# 14  15           Getafe  35  10   9  16  31  34  -3   39    1.11  34.4  43.2
# 15  16         Espanyol  35  10   9  16  38  47  -9   39    1.11  30.3  51.4
# 16  17           Alavés  35   8  11  16  35  47 -12   35    1.00  37.7  43.0
# 17  18          Leganés  35   7  13  15  35  53 -18   34    0.97  31.4  56.8
# 18  19       Las Palmas  36   8   8  20  40  58 -18   32    0.89  35.2  63.1
# 19  20       Valladolid  36   4   4  28  26  86 -60   16    0.44  32.6  64.1
#
#      xGD  xGD/90     Last 5  Attendance                   Top Team Scorer  \
# 0   48.4    1.38  W W W W W       45752           Robert Lewandowski - 25
# 1   27.2    0.78  W W W W L       70140                Kylian Mbappé - 27
# 2   23.9    0.68  W L W D W       60806            Alexander Sørloth - 17
# 3   16.1    0.46  W L W D W       48319                 Oihan Sancet - 15
# 4   19.9    0.57  D L W W W       18367                  Ayoze Pérez - 16
# 5    7.7    0.22  L W W W D       51564        Isco, Giovani Lo Celso - 8
# 6    8.6    0.24  L W L W W       21506               Borja Iglesias - 10
# 7   -3.9   -0.11  L D L W W       12819  Álvaro García, Pathé Ciss... - 4
# 8   -3.2   -0.09  W D L L W       18524                  Vedat Muriqi - 7
# 9   -9.0   -0.26  W W W L D       20397                 Ante Budimir - 19
# 10  -6.9   -0.20  W D D W W       42897                    Hugo Duro - 11
# 11   0.5    0.01  D L D L L       29964               Mikel Oyarzabal - 8
# 12  -5.6   -0.16  L D W L W       11663             Cristhian Stuani - 10
# 13  -3.8   -0.11  D L D L W       35793               Dodi Lukebakio - 11
# 14  -8.8   -0.25  L L L L L       11381               Mauro Arambarri - 9
# 15 -21.1   -0.60  W D L L L       24727                   Javi Puado - 11
# 16  -5.3   -0.15  L D W D L       17185                         Kiké - 12
# 17 -25.5   -0.73  L D D D W       11113                     Dani Raba - 7
# 18 -27.9   -0.77  W L L L L       23662                  Fábio Silva - 10
# 19 -31.4   -0.87  L L L L L       20127                 Mamadou Sylla - 5
#
#               Goalkeeper  Notes
# 0             Iñaki Peña    NaN
# 1       Thibaut Courtois    NaN
# 2              Jan Oblak    NaN
# 3             Unai Simón    NaN
# 4            Diego Conde    NaN
# 5                 Adrián    NaN
# 6         Vicente Guaita    NaN
# 7        Augusto Batalla    NaN
# 8          Dominik Greif    NaN
# 9         Sergio Herrera    NaN
# 10  Giorgi Mamardashvili    NaN
# 11           Álex Remiro    NaN
# 12       Paulo Gazzaniga    NaN
# 13          Ørjan Nyland    NaN
# 14           David Soria    NaN
# 15           Joan García    NaN
# 16        Antonio Sivera    NaN
# 17       Marko Dmitrović    NaN
# 18      Jasper Cillessen    NaN
# 19       Karl Jakob Hein    NaN

# %%
df['Badge']=df['Squad'].apply(
    lambda x: f"/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/La Liga Team Logos/{x.lower().replace('é','e')}_logo.png"
)

# %%
df['Badge'].tolist()
# Out:
# ['/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/La Liga Team Logos/barcelona_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/La Liga Team Logos/real madrid_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/La Liga Team Logos/atletico madrid_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/La Liga Team Logos/athletic club_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/La Liga Team Logos/villarreal_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/La Liga Team Logos/betis_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/La Liga Team Logos/celta vigo_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/La Liga Team Logos/rayo vallecano_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/La Liga Team Logos/mallorca_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/La Liga Team Logos/osasuna_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/La Liga Team Logos/valencia_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/La Liga Team Logos/real sociedad_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/La Liga Team Logos/girona_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/La Liga Team Logos/sevilla_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/La Liga Team Logos/getafe_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/La Liga Team Logos/espanyol_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/La Liga Team Logos/alaves_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/La Liga Team Logos/leganes_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/La Liga Team Logos/las palmas_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/La Liga Team Logos/valladolid_logo.png']

# %%
df
# Out:
#     Rk                                              Badge            Squad  \
# 0    1  /Users/siphuvuyomngxunyeni/Downloads/Football ...        Barcelona
# 1    2  /Users/siphuvuyomngxunyeni/Downloads/Football ...      Real Madrid
# 2    3  /Users/siphuvuyomngxunyeni/Downloads/Football ...  Atlético Madrid
# 3    4  /Users/siphuvuyomngxunyeni/Downloads/Football ...    Athletic Club
# 4    5  /Users/siphuvuyomngxunyeni/Downloads/Football ...       Villarreal
# 5    6  /Users/siphuvuyomngxunyeni/Downloads/Football ...            Betis
# 6    7  /Users/siphuvuyomngxunyeni/Downloads/Football ...       Celta Vigo
# 7    8  /Users/siphuvuyomngxunyeni/Downloads/Football ...   Rayo Vallecano
# 8    9  /Users/siphuvuyomngxunyeni/Downloads/Football ...         Mallorca
# 9   10  /Users/siphuvuyomngxunyeni/Downloads/Football ...          Osasuna
# 10  11  /Users/siphuvuyomngxunyeni/Downloads/Football ...         Valencia
# 11  12  /Users/siphuvuyomngxunyeni/Downloads/Football ...    Real Sociedad
# 12  13  /Users/siphuvuyomngxunyeni/Downloads/Football ...           Girona
# 13  14  /Users/siphuvuyomngxunyeni/Downloads/Football ...          Sevilla
# 14  15  /Users/siphuvuyomngxunyeni/Downloads/Football ...           Getafe
# 15  16  /Users/siphuvuyomngxunyeni/Downloads/Football ...         Espanyol
# 16  17  /Users/siphuvuyomngxunyeni/Downloads/Football ...           Alavés
# 17  18  /Users/siphuvuyomngxunyeni/Downloads/Football ...          Leganés
# 18  19  /Users/siphuvuyomngxunyeni/Downloads/Football ...       Las Palmas
# 19  20  /Users/siphuvuyomngxunyeni/Downloads/Football ...       Valladolid
#
#     MP   W   D   L  GF  GA  GD  Pts  Pts/MP    xG   xGA   xGD  xGD/90
# 0   35  26   4   5  95  36  59   82    2.34  86.0  37.6  48.4    1.38
# 1   35  23   6   6  72  37  35   75    2.14  68.1  40.9  27.2    0.78
# 2   35  20  10   5  60  27  33   70    2.00  55.8  31.9  23.9    0.68
# 3   35  17  13   5  51  26  25   64    1.83  49.5  33.4  16.1    0.46
# 4   35  17  10   8  61  47  14   61    1.74  60.4  40.5  19.9    0.57
# 5   35  16  10   9  53  43  10   58    1.66  51.6  43.9   7.7    0.22
# 6   36  15   7  14  56  54   2   52    1.44  50.3  41.7   8.6    0.24
# 7   35  12  11  12  37  42  -5   47    1.34  40.9  44.8  -3.9   -0.11
# 8   35  13   8  14  33  40  -7   47    1.34  37.2  40.4  -3.2   -0.09
# 9   35  10  15  10  43  51  -8   45    1.29  40.6  49.6  -9.0   -0.26
# 10  35  11  12  12  43  51  -8   45    1.29  41.2  48.1  -6.9   -0.20
# 11  36  12   7  17  32  42 -10   43    1.19  39.6  39.1   0.5    0.01
# 12  36  11   8  17  42  53 -11   41    1.14  40.1  45.7  -5.6   -0.16
# 13  36  10  11  15  40  49  -9   41    1.14  40.5  44.3  -3.8   -0.11
# 14  35  10   9  16  31  34  -3   39    1.11  34.4  43.2  -8.8   -0.25
# 15  35  10   9  16  38  47  -9   39    1.11  30.3  51.4 -21.1   -0.60
# 16  35   8  11  16  35  47 -12   35    1.00  37.7  43.0  -5.3   -0.15
# 17  35   7  13  15  35  53 -18   34    0.97  31.4  56.8 -25.5   -0.73
# 18  36   8   8  20  40  58 -18   32    0.89  35.2  63.1 -27.9   -0.77
# 19  36   4   4  28  26  86 -60   16    0.44  32.6  64.1 -31.4   -0.87

# %%
df.columns
# Out:
# Index(['Rk', 'Badge', 'Squad', 'MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts',
#        'Pts/MP', 'xG', 'xGA', 'xGD', 'xGD/90'],
#       dtype='object')

# %%
#Some data cleaning
df=df[['Rk','Badge','Squad','MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Pts/MP',
       'xG', 'xGA', 'xGD', 'xGD/90']]

# %%
df
# Out:
#     Rk                                              Badge            Squad  \
# 0    1  /Users/siphuvuyomngxunyeni/Downloads/Football ...        Barcelona
# 1    2  /Users/siphuvuyomngxunyeni/Downloads/Football ...      Real Madrid
# 2    3  /Users/siphuvuyomngxunyeni/Downloads/Football ...  Atlético Madrid
# 3    4  /Users/siphuvuyomngxunyeni/Downloads/Football ...    Athletic Club
# 4    5  /Users/siphuvuyomngxunyeni/Downloads/Football ...       Villarreal
# 5    6  /Users/siphuvuyomngxunyeni/Downloads/Football ...            Betis
# 6    7  /Users/siphuvuyomngxunyeni/Downloads/Football ...       Celta Vigo
# 7    8  /Users/siphuvuyomngxunyeni/Downloads/Football ...   Rayo Vallecano
# 8    9  /Users/siphuvuyomngxunyeni/Downloads/Football ...         Mallorca
# 9   10  /Users/siphuvuyomngxunyeni/Downloads/Football ...          Osasuna
# 10  11  /Users/siphuvuyomngxunyeni/Downloads/Football ...         Valencia
# 11  12  /Users/siphuvuyomngxunyeni/Downloads/Football ...    Real Sociedad
# 12  13  /Users/siphuvuyomngxunyeni/Downloads/Football ...           Girona
# 13  14  /Users/siphuvuyomngxunyeni/Downloads/Football ...          Sevilla
# 14  15  /Users/siphuvuyomngxunyeni/Downloads/Football ...           Getafe
# 15  16  /Users/siphuvuyomngxunyeni/Downloads/Football ...         Espanyol
# 16  17  /Users/siphuvuyomngxunyeni/Downloads/Football ...           Alavés
# 17  18  /Users/siphuvuyomngxunyeni/Downloads/Football ...          Leganés
# 18  19  /Users/siphuvuyomngxunyeni/Downloads/Football ...       Las Palmas
# 19  20  /Users/siphuvuyomngxunyeni/Downloads/Football ...       Valladolid
#
#     MP   W   D   L  GF  GA  GD  Pts  Pts/MP    xG   xGA   xGD  xGD/90
# 0   35  26   4   5  95  36  59   82    2.34  86.0  37.6  48.4    1.38
# 1   35  23   6   6  72  37  35   75    2.14  68.1  40.9  27.2    0.78
# 2   35  20  10   5  60  27  33   70    2.00  55.8  31.9  23.9    0.68
# 3   35  17  13   5  51  26  25   64    1.83  49.5  33.4  16.1    0.46
# 4   35  17  10   8  61  47  14   61    1.74  60.4  40.5  19.9    0.57
# 5   35  16  10   9  53  43  10   58    1.66  51.6  43.9   7.7    0.22
# 6   36  15   7  14  56  54   2   52    1.44  50.3  41.7   8.6    0.24
# 7   35  12  11  12  37  42  -5   47    1.34  40.9  44.8  -3.9   -0.11
# 8   35  13   8  14  33  40  -7   47    1.34  37.2  40.4  -3.2   -0.09
# 9   35  10  15  10  43  51  -8   45    1.29  40.6  49.6  -9.0   -0.26
# 10  35  11  12  12  43  51  -8   45    1.29  41.2  48.1  -6.9   -0.20
# 11  36  12   7  17  32  42 -10   43    1.19  39.6  39.1   0.5    0.01
# 12  36  11   8  17  42  53 -11   41    1.14  40.1  45.7  -5.6   -0.16
# 13  36  10  11  15  40  49  -9   41    1.14  40.5  44.3  -3.8   -0.11
# 14  35  10   9  16  31  34  -3   39    1.11  34.4  43.2  -8.8   -0.25
# 15  35  10   9  16  38  47  -9   39    1.11  30.3  51.4 -21.1   -0.60
# 16  35   8  11  16  35  47 -12   35    1.00  37.7  43.0  -5.3   -0.15
# 17  35   7  13  15  35  53 -18   34    0.97  31.4  56.8 -25.5   -0.73
# 18  36   8   8  20  40  58 -18   32    0.89  35.2  63.1 -27.9   -0.77
# 19  36   4   4  28  26  86 -60   16    0.44  32.6  64.1 -31.4   -0.87

# %%
# Set up the colors
# Used Coolors to get the color hex codes: https://coolors.co/?ref=65623355a0453d000b8a2708
bg_color = "#FFFFFF" # I usually just like to do a white background
text_color = "#000000" # With black text

row_colors = {
"even": "#E2E2E1",
"odd": "#B3B0B0",
}

plt.rcParams["text.color"] = text_color
plt.rcParams["font.family"] = "monospace"

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
from plottable import ColumnDefinition, Table
from plottable.plots import image
import matplotlib

from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.colors import LinearSegmentedColormap

from plottable import ColumnDefinition, Table
from plottable.plots import *

col_defs=[
    ColumnDefinition(
        name="Rk",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="Badge",
        textprops={"ha": "right", "va": "center", 'color': bg_color},
        width=0.5,
        plot_fn=image,
    ),
    ColumnDefinition(
        name="Squad",
        textprops={"ha": "left"},
        width=1.75,
    ),
    ColumnDefinition(
        name="MP",
        group="Matches Played",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="W",
        group="Matches Played",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="D",
        group="Matches Played",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="L",
        group="Matches Played",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="GF",
        group="Goals",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="GA",
        group="Goals",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="GD",
        group="Goals",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="Pts",
        group="Points",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="Pts/MP",
        group="Points",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="xG",
        group="Expected Goals",
        textprops={"ha": "center", "color": "#000000", "weight": "bold", "bbox": {"boxstyle": "circle", "pad": 0.35}},
        cmap=normed_cmap(df["xG"], cmap=matplotlib.cm.PiYG, num_stds=2)
    ),
    ColumnDefinition(
        name="xGA",
        group="Expected Goals",
        textprops={"ha": "center", "color": "#000000", "weight": "bold", "bbox": {"boxstyle": "circle", "pad": 0.35}},
        cmap=normed_cmap(df["xGA"], cmap=matplotlib.cm.PiYG_r, num_stds=2)
    ),
    ColumnDefinition(
        name="xGD",
        group="Expected Goals",
        textprops={"ha": "center", "color": "#000000", "weight": "bold", "bbox": {"boxstyle": "circle", "pad": 0.35}},
        cmap=normed_cmap(df["xGD"], cmap=matplotlib.cm.PiYG, num_stds=2)
    ),
    ColumnDefinition(
        name="xGD/90",
        textprops={"ha": "center", "color": "#000000", "weight": "bold", "bbox": {"boxstyle": "circle", "pad": 0.35}},
        cmap=normed_cmap(df["xGD/90"], cmap=matplotlib.cm.PiYG, num_stds=2)
    ),
    ColumnDefinition(
        name="Top Scorer Images",
        textprops={"ha":"center", 'color': bg_color},
        plot_fn=image,
        width=1.5,
    ),
    ColumnDefinition(
        name="Top Team Scorer",
        textprops={"ha":"center"},
        width=1.75,
),
]

# %%
from matplotlib.lines import Line2D
from PIL import Image
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

fig, ax = plt.subplots(figsize=(20, 22))
fig.set_facecolor(bg_color)
ax.set_facecolor(bg_color)
table = Table(
    df,
    column_definitions=col_defs,
    index_col="Rk",
    row_dividers=True,
    row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    footer_divider=True,
    textprops={"fontsize": 14},
    col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    column_border_kw={"linewidth": .5, "linestyle": "-"},
    ax=ax,
).autoset_fontcolors(colnames=["xG", "xGA", "xGD"])

#League badge
club_image=Image.open('/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/LaLiga_EA_Sports_2023_Vertical_Logo.png')
imagebox=OffsetImage(club_image, zoom=0.3)
ab=AnnotationBbox(imagebox, (0.07,1.01), frameon=True, xycoords='axes fraction')
ax.add_artist(ab)

#Add title at the top
fig.suptitle('2024-25 La Liga Stats', fontsize=28, color=text_color, weight='bold', y=0.9)

plt.savefig("/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/LaLiga 2024-25 Table.png",
    facecolor= ax.get_facecolor(),
    dpi=200,
    bbox_inches="tight",
)
fig.show()
# Out:
# /var/folders/tc/b844__mx5sl6dq_8zjb208yh0000gn/T/ipykernel_71296/4210063999.py:35: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
