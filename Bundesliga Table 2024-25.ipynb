# 13  -9.4   -0.28  W D D L D       29503             Morgan Guilavogui - 6
# 14 -12.1   -0.37  W L L D D       25006              Andrej Kramarić - 11
# 15 -16.7   -0.51  L L W D W       15000              Marvin Pieringer - 7
# 16 -19.5   -0.59  L D W W L       14893                Shuto Machino - 11
# 17 -21.9   -0.66  L L D D L       25540                   Myron Boadu - 7
#
#           Goalkeeper  Notes
# 0       Manuel Neuer    NaN
# 1     Lukáš Hrádecký    NaN
# 2        Kevin Trapp    NaN
# 3       Noah Atubolu    NaN
# 4       Gregor Kobel    NaN
# 5      Robin Zentner    NaN
# 6      Péter Gulácsi    NaN
# 7   Michael Zetterer    NaN
# 8    Alexander Nübel    NaN
# 9     Moritz Nicolas    NaN
# 10       Finn Dahmen    NaN
# 11     Kamil Grabara    NaN
# 12   Frederik Rønnow    NaN
# 13     Nikola Vasilj    NaN
# 14    Oliver Baumann    NaN
# 15      Kevin Müller    NaN
# 16      Timon Weiner    NaN
# 17    Patrick Drewes    NaN

# %%
df['Badge']=df['Squad'].apply(
    lambda x: f"/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Bundesliga Team Logos/{x.lower()}_logo.png"
)

# %%
df['Badge'].tolist()
# Out:
# ['/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Bundesliga Team Logos/bayern munich_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Bundesliga Team Logos/leverkusen_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Bundesliga Team Logos/eint frankfurt_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Bundesliga Team Logos/freiburg_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Bundesliga Team Logos/dortmund_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Bundesliga Team Logos/mainz 05_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Bundesliga Team Logos/rb leipzig_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Bundesliga Team Logos/werder bremen_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Bundesliga Team Logos/stuttgart_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Bundesliga Team Logos/gladbach_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Bundesliga Team Logos/augsburg_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Bundesliga Team Logos/wolfsburg_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Bundesliga Team Logos/union berlin_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Bundesliga Team Logos/st. pauli_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Bundesliga Team Logos/hoffenheim_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Bundesliga Team Logos/heidenheim_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Bundesliga Team Logos/holstein kiel_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Bundesliga Team Logos/bochum_logo.png']

# %%
df.columns
# Out:
# Index(['Rk', 'Squad', 'MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Pts/MP',
#        'xG', 'xGA', 'xGD', 'xGD/90', 'Last 5', 'Attendance', 'Top Team Scorer',
#        'Goalkeeper', 'Notes', 'Badge'],
#       dtype='object')

# %%
#Some data cleaning
df=df[['Rk','Badge','Squad','MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Pts/MP',
       'xG', 'xGA', 'xGD', 'xGD/90']]

# %%
df
# Out:
#     Rk                                              Badge           Squad  MP  \
# 0    1  /Users/siphuvuyomngxunyeni/Downloads/Football ...   Bayern Munich  33
# 1    2  /Users/siphuvuyomngxunyeni/Downloads/Football ...      Leverkusen  33
# 2    3  /Users/siphuvuyomngxunyeni/Downloads/Football ...  Eint Frankfurt  33
# 3    4  /Users/siphuvuyomngxunyeni/Downloads/Football ...        Freiburg  33
# 4    5  /Users/siphuvuyomngxunyeni/Downloads/Football ...        Dortmund  33
# 5    6  /Users/siphuvuyomngxunyeni/Downloads/Football ...        Mainz 05  33
# 6    7  /Users/siphuvuyomngxunyeni/Downloads/Football ...      RB Leipzig  33
# 7    8  /Users/siphuvuyomngxunyeni/Downloads/Football ...   Werder Bremen  33
# 8    9  /Users/siphuvuyomngxunyeni/Downloads/Football ...       Stuttgart  33
# 9   10  /Users/siphuvuyomngxunyeni/Downloads/Football ...        Gladbach  33
# 10  11  /Users/siphuvuyomngxunyeni/Downloads/Football ...        Augsburg  33
# 11  12  /Users/siphuvuyomngxunyeni/Downloads/Football ...       Wolfsburg  33
# 12  13  /Users/siphuvuyomngxunyeni/Downloads/Football ...    Union Berlin  33
# 13  14  /Users/siphuvuyomngxunyeni/Downloads/Football ...       St. Pauli  33
# 14  15  /Users/siphuvuyomngxunyeni/Downloads/Football ...      Hoffenheim  33
# 15  16  /Users/siphuvuyomngxunyeni/Downloads/Football ...      Heidenheim  33
# 16  17  /Users/siphuvuyomngxunyeni/Downloads/Football ...   Holstein Kiel  33
# 17  18  /Users/siphuvuyomngxunyeni/Downloads/Football ...          Bochum  33
#
#      W   D   L  GF  GA  GD  Pts  Pts/MP    xG   xGA   xGD  xGD/90
# 0   24   7   2  95  32  63   79    2.39  80.3  25.1  55.2    1.67
# 1   19  11   3  70  41  29   68    2.06  56.0  33.4  22.6    0.68
# 2   16   9   8  65  45  20   57    1.73  63.0  47.3  15.7    0.48
# 3   16   7  10  48  50  -2   55    1.67  43.5  40.5   3.1    0.09
# 4   16   6  11  68  51  17   54    1.64  59.0  42.4  16.6    0.50
# 5   14   9  10  53  41  12   51    1.55  47.1  46.9   0.2    0.00
# 6   13  12   8  51  45   6   51    1.55  45.5  50.8  -5.3   -0.16
# 7   13   9  11  50  56  -6   48    1.45  46.9  46.5   0.4    0.01
# 8   13   8  12  61  51  10   47    1.42  59.8  45.8  14.0    0.42
# 9   13   6  14  55  56  -1   45    1.36  49.6  61.7 -12.1   -0.37
# 10  11  10  12  34  49 -15   43    1.30  33.0  48.1 -15.1   -0.46
# 11  10  10  13  55  54   1   40    1.21  45.8  51.6  -5.7   -0.17
# 12   9  10  14  33  50 -17   37    1.12  36.2  46.1  -9.8   -0.30
# 13   8   8  17  28  39 -11   32    0.97  34.6  43.9  -9.4   -0.28
# 14   7  11  15  46  64 -18   32    0.97  42.2  54.3 -12.1   -0.37
# 15   8   5  20  36  60 -24   29    0.88  38.7  55.4 -16.7   -0.51
# 16   6   7  20  49  77 -28   25    0.76  39.1  58.6 -19.5   -0.59
# 17   5   7  21  31  67 -36   22    0.67  40.5  62.4 -21.9   -0.66

# %%
# Set up the colors
# Used Coolors to get the color hex codes: https://coolors.co/?ref=65623355a0453d000b8a2708
bg_color = "#FFFFFF" # I usually just like to do a white background
text_color = "#000000" # With black text

row_colors = {
"even": "#E2E2E1",
"odd": "#B3B0B0",
}

plt.rcParams["text.color"] = text_color
plt.rcParams["font.family"] = "monospace"

# %%
col_defs=[
    ColumnDefinition(
        name="Rk",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="Badge",
        textprops={"ha": "right", "va": "center", 'color': bg_color},
        width=0.5,
        plot_fn=image,
    ),
    ColumnDefinition(
        name="Squad",
        textprops={"ha": "left"},
        width=1.75,
    ),
    ColumnDefinition(
        name="MP",
        group="Matches Played",
        textprops={"ha": "center", "weight": "bold"},
        width=0.5,
    ),
    ColumnDefinition(
        name="W",
        group="Matches Played",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="D",
        group="Matches Played",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="L",
        group="Matches Played",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="GF",
        group="Goals",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="GA",
        group="Goals",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="GD",
        group="Goals",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="Pts",
        group="Points",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="Pts/MP",
        group="Points",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="xG",
        group="Expected Goals",
        textprops={"ha": "center", "color": "#000000", "weight": "bold", "bbox": {"boxstyle": "circle", "pad": 0.35}},
        cmap=normed_cmap(df["xG"], cmap=matplotlib.cm.PiYG, num_stds=2)
    ),
    ColumnDefinition(
        name="xGA",
        group="Expected Goals",
        textprops={"ha": "center", "color": "#000000", "weight": "bold", "bbox": {"boxstyle": "circle", "pad": 0.35}},
        cmap=normed_cmap(df["xGA"], cmap=matplotlib.cm.PiYG_r, num_stds=2)
    ),
    ColumnDefinition(
        name="xGD",
        group="Expected Goals",
        textprops={"ha": "center", "color": "#000000", "weight": "bold", "bbox": {"boxstyle": "circle", "pad": 0.35}},
        cmap=normed_cmap(df["xGD"], cmap=matplotlib.cm.PiYG, num_stds=2)
    ),
    ColumnDefinition(
        name="xGD/90",
        textprops={"ha": "center", "color": "#000000", "weight": "bold", "bbox": {"boxstyle": "circle", "pad": 0.35}},
        cmap=normed_cmap(df["xGD/90"], cmap=matplotlib.cm.PiYG, num_stds=2)
),
    ColumnDefinition(
        name="Top Scorer Image",
        textprops={"ha":"center", 'color': bg_color},
        plot_fn=image,
        width=0.75,
),
    ColumnDefinition(
        name="Top Team Scorer",
        textprops={"ha":"center"},
        width=1.75,
),
]

# %%
from matplotlib.lines import Line2D
from PIL import Image
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

fig, ax = plt.subplots(figsize=(20, 22))
fig.set_facecolor(bg_color)
ax.set_facecolor(bg_color)
table = Table(
    df,
    column_definitions=col_defs,
    index_col="Rk",
    row_dividers=True,
    row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    footer_divider=True,
    textprops={"fontsize": 14},
    col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    column_border_kw={"linewidth": .5, "linestyle": "-"},
    ax=ax,
).autoset_fontcolors(colnames=["xG", "xGA", "xGD"])

#League badge
club_image=Image.open('/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Bundesliga_logo.png')
imagebox=OffsetImage(club_image, zoom=0.35)
ab=AnnotationBbox(imagebox, (0.05,0.99), frameon=True, xycoords='axes fraction')
ax.add_artist(ab)

#Add title at the top
fig.suptitle('2024-25 Bundesliga Stats', fontsize=28, color=text_color, weight='bold', y=0.9)

plt.savefig("/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Bundesliga 2024-25 Table using quick method.png",
    facecolor= ax.get_facecolor(),
    dpi=200,
    bbox_inches="tight",
)
fig.show()
# Out:
# /var/folders/tc/b844__mx5sl6dq_8zjb208yh0000gn/T/ipykernel_52104/3517696726.py:35: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
