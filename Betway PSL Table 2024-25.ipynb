# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

from plottable import ColumnDefinition, Table
from plottable.cmap import normed_cmap
from plottable.plots import image

# %%
df=pd.read_html('https://fbref.com/en/comps/52/Premier-Division-Stats', attrs={"id":"results2024-2025521_overall"})[0]

# %%
df
# Out:
#     Rk                 Squad  MP   W   D   L  GF  GA  GD  Pts  Pts/MP  \
# 0    1              Sundowns  26  22   1   3  58  12  46   67    2.58
# 1    2       Orlando Pirates  24  18   1   5  39  17  22   55    2.29
# 2    3  Sekhukhune United FC  26  13   6   7  34  25   9   45    1.73
# 3    4       Stellenbosch FC  25  11   8   6  30  19  11   41    1.64
# 4    5             TS Galaxy  28   9  10   9  32  30   2   37    1.32
# 5    6               AmaZulu  28  11   4  13  30  34  -4   37    1.32
# 6    7        Polokwane City  27   9   9   9  20  23  -3   36    1.33
# 7    8         Kaizer Chiefs  27   8   7  12  26  33  -7   31    1.15
# 8    9             Magesi FC  24   8   6  10  15  21  -6   30    1.25
# 9   10       Richards Bay FC  27   8   6  13  17  26  -9   30    1.11
# 10  11    Marumo Gallants FC  26   8   6  12  24  37 -13   30    1.15
# 11  12         Golden Arrows  26   7   8  11  19  31 -12   29    1.12
# ...

# %%
df['Badge']=df['Squad'].apply(
    lambda x: f"/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/PSL Team Logos/{x.lower()}_logo.png"
)

# %%
df['Badge'].tolist()
# Out:
# ['/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/PSL Team Logos/sundowns_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/PSL Team Logos/orlando pirates_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/PSL Team Logos/sekhukhune united fc_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/PSL Team Logos/stellenbosch fc_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/PSL Team Logos/ts galaxy_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/PSL Team Logos/amazulu_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/PSL Team Logos/polokwane city_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/PSL Team Logos/kaizer chiefs_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/PSL Team Logos/magesi fc_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/PSL Team Logos/richards bay fc_logo.png',
# ...

# %%
df['Goalkeeper Images']=df['Goalkeeper'].apply(
    lambda x: f"/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/PSL Goalkeepers/{x.lower().replace('é','e')}_gk.png"
)

# %%
df
# Out:
#     Rk                                              Badge  \
# 0    1  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 1    2  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 2    3  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 3    4  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 4    5  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 5    6  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 6    7  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 7    8  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 8    9  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 9   10  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 10  11  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 11  12  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 12  13  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 13  14  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 14  15  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# ...

# %%
#Some data cleaning
df=df[['Rk','Badge','Squad','MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Pts/MP',
      'Goalkeeper Images','Goalkeeper']]

# %%
df
# Out:
#     Rk                                              Badge  \
# 0    1  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 1    2  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 2    3  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 3    4  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 4    5  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 5    6  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 6    7  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 7    8  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 8    9  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 9   10  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 10  11  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 11  12  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 12  13  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 13  14  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# 14  15  /Users/siphuvuyomngxunyeni/Downloads/Football ...
# ...

# %%
# Set up the colors
# Used Coolors to get the color hex codes: https://coolors.co/?ref=65623355a0453d000b8a2708
bg_color = "#FFFFFF" # I usually just like to do a white background
text_color = "#000000" # With black text

row_colors = {
"top 5":"#BAFF71",
"top 7":"#5C95FF",
"relegation":"#FF8D8D",
"even": "#E2E2E1",
"odd": "#B3B0B0",
}

plt.rcParams["text.color"] = text_color
plt.rcParams["font.family"] = "monospace"

# %%
from PIL import Image
import pandas as pd
import os
import matplotlib.pyplot as plt
from plottable import ColumnDefinition, Table
from plottable.plots import image
import matplotlib

from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.colors import LinearSegmentedColormap

from plottable import ColumnDefinition, Table
from plottable.plots import *

col_defs=[
    ColumnDefinition(
        name="Rk",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="Badge",
        textprops={"ha": "right", "va": "center", 'color': bg_color},
        width=0.5,
        plot_fn=image,
    ),
    ColumnDefinition(
        name="Squad",
        textprops={"ha": "left"},
        width=1.75,
    ),
    ColumnDefinition(
        name="MP",
        group="Matches Played",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="W",
        group="Matches Played",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="D",
        group="Matches Played",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="L",
        group="Matches Played",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="GF",
        group="Goals",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="GA",
        group="Goals",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="GD",
        group="Goals",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="Pts",
        group="Points",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="Pts/MP",
        group="Points",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="Goalkeeper Images",
        textprops={"ha":"center", 'color': bg_color},
        plot_fn=image,
        width=0.75,
    ),
    ColumnDefinition(
        name="Goalkeeper",
        textprops={"ha":"center"},
        width=1.75,
),
]

# %%
from matplotlib.lines import Line2D
from PIL import Image
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

fig, ax = plt.subplots(figsize=(20, 22))
fig.set_facecolor(bg_color)
ax.set_facecolor(bg_color)
table = Table(
    df,
    column_definitions=col_defs,
    index_col="Rk",
    row_dividers=True,
    row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    footer_divider=True,
    textprops={"fontsize": 14},
    col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    column_border_kw={"linewidth": .5, "linestyle": "-"},
    ax=ax,
)

#League badge
club_image=Image.open('/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Betway Premiership.png')
imagebox=OffsetImage(club_image, zoom=0.4)
ab=AnnotationBbox(imagebox, (0.06,0.99), frameon=True, xycoords='axes fraction')
ax.add_artist(ab)

#Add title at the top
fig.suptitle('2024-25 Betway Premiership Stats', fontsize=28, color=text_color, weight='bold', y=0.9)

plt.savefig("/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Betway 2024-25 Table.png",
    facecolor= ax.get_facecolor(),
    dpi=200,
    bbox_inches="tight",
)
fig.show()
# Out:
# /var/folders/tc/b844__mx5sl6dq_8zjb208yh0000gn/T/ipykernel_73386/2199499264.py:35: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
