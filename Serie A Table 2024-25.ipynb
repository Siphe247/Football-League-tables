# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

from plottable import ColumnDefinition, Table
from plottable.cmap import normed_cmap
from plottable.plots import image

# %%
df=pd.read_html('https://fbref.com/en/comps/11/Serie-A-Stats', attrs={"id":"results2024-2025111_overall"})[0]

# %%
df
# Out:
#     Rk          Squad  MP   W   D   L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0    1         Napoli  36  23   9   4  57  27  30   78    2.17  50.2  29.0
# 1    2          Inter  36  23   8   5  75  33  42   77    2.14  64.4  33.1
# 2    3       Atalanta  36  21   8   7  73  32  41   71    1.97  61.8  34.9
# 3    4       Juventus  36  16  16   4  53  33  20   64    1.78  47.4  32.8
# 4    5          Lazio  36  18  10   8  59  46  13   64    1.78  53.3  36.2
# 5    6           Roma  36  18   9   9  51  34  17   63    1.75  50.0  39.0
# 6    7        Bologna  36  16  14   6  54  41  13   62    1.72  46.1  34.0
# 7    8          Milan  36  17   9  10  58  40  18   60    1.67  60.8  39.9
# 8    9     Fiorentina  36  17   8  11  54  37  17   59    1.64  44.4  38.9
# 9   10           Como  36  13   9  14  48  49  -1   48    1.33  43.4  40.2
# 10  11         Torino  36  10  14  12  39  42  -3   44    1.22  33.6  47.7
# ...

# %%
df['Badge']=df['Squad'].apply(
    lambda x: f"/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Serie A Team Logos/{x.lower()}_logo.png"
)

# %%
df['Badge'].tolist()
# Out:
# ['/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Serie A Team Logos/napoli_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Serie A Team Logos/inter_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Serie A Team Logos/atalanta_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Serie A Team Logos/juventus_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Serie A Team Logos/lazio_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Serie A Team Logos/roma_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Serie A Team Logos/bologna_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Serie A Team Logos/milan_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Serie A Team Logos/fiorentina_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Serie A Team Logos/como_logo.png',
# ...

# %%
df
# Out:
#     Rk          Squad  MP   W   D   L  GF  GA  GD  Pts  ...    xG   xGA   xGD  \
# 0    1         Napoli  36  23   9   4  57  27  30   78  ...  50.2  29.0  21.1
# 1    2          Inter  36  23   8   5  75  33  42   77  ...  64.4  33.1  31.2
# 2    3       Atalanta  36  21   8   7  73  32  41   71  ...  61.8  34.9  26.9
# 3    4       Juventus  36  16  16   4  53  33  20   64  ...  47.4  32.8  14.6
# 4    5          Lazio  36  18  10   8  59  46  13   64  ...  53.3  36.2  17.1
# 5    6           Roma  36  18   9   9  51  34  17   63  ...  50.0  39.0  11.0
# 6    7        Bologna  36  16  14   6  54  41  13   62  ...  46.1  34.0  12.1
# 7    8          Milan  36  17   9  10  58  40  18   60  ...  60.8  39.9  20.9
# 8    9     Fiorentina  36  17   8  11  54  37  17   59  ...  44.4  38.9   5.5
# 9   10           Como  36  13   9  14  48  49  -1   48  ...  43.4  40.2   3.3
# 10  11         Torino  36  10  14  12  39  42  -3   44  ...  33.6  47.7 -14.0
# ...

# %%
df['Top Team Scorer Images']=df['Top Team Scorer'].apply(
    lambda x: f"/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Serie A Top Team Scorer Images/{x.lower().replace('ć','c').replace('í','i').replace('š','s')}_sa.png"
)

# %%
df['Top Team Scorer Images'].tolist()
# Out:
# ['/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Serie A Top Team Scorer Images/romelu lukaku - 13_sa.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Serie A Top Team Scorer Images/marcus thuram - 14_sa.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Serie A Top Team Scorer Images/mateo retegui - 24_sa.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Serie A Top Team Scorer Images/dusan vlahovic - 9_sa.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Serie A Top Team Scorer Images/valentin castellanos - 10_sa.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Serie A Top Team Scorer Images/artem dovbyk - 12_sa.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Serie A Top Team Scorer Images/riccardo orsolini - 13_sa.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Serie A Top Team Scorer Images/christian pulisic - 11_sa.png',
# ...

# %%
df.columns
# Out:
# Index(['Rk', 'Squad', 'MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Pts/MP',
#        'xG', 'xGA', 'xGD', 'xGD/90', 'Last 5', 'Attendance', 'Top Team Scorer',
#        'Goalkeeper', 'Notes', 'Badge', 'Top Team Scorer Images'],
#       dtype='object')

# %%
#Some data cleaning
df=df[['Rk','Badge','Squad','MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Pts/MP',
       'xG', 'xGA', 'xGD', 'xGD/90', 'Top Team Scorer Images','Top Team Scorer']]

# %%
df
# Out:
#     Rk                                              Badge          Squad  MP  \
# 0    1  /Users/siphuvuyomngxunyeni/Downloads/Football ...         Napoli  36
# 1    2  /Users/siphuvuyomngxunyeni/Downloads/Football ...          Inter  36
# 2    3  /Users/siphuvuyomngxunyeni/Downloads/Football ...       Atalanta  36
# 3    4  /Users/siphuvuyomngxunyeni/Downloads/Football ...       Juventus  36
# 4    5  /Users/siphuvuyomngxunyeni/Downloads/Football ...          Lazio  36
# 5    6  /Users/siphuvuyomngxunyeni/Downloads/Football ...           Roma  36
# 6    7  /Users/siphuvuyomngxunyeni/Downloads/Football ...        Bologna  36
# 7    8  /Users/siphuvuyomngxunyeni/Downloads/Football ...          Milan  36
# 8    9  /Users/siphuvuyomngxunyeni/Downloads/Football ...     Fiorentina  36
# 9   10  /Users/siphuvuyomngxunyeni/Downloads/Football ...           Como  36
# 10  11  /Users/siphuvuyomngxunyeni/Downloads/Football ...         Torino  36
# ...

# %%
# Set up the colors
# Used Coolors to get the color hex codes: https://coolors.co/?ref=65623355a0453d000b8a2708
bg_color = "#FFFFFF" # I usually just like to do a white background
text_color = "#000000" # With black text

row_colors = {
"even": "#E2E2E1",
"odd": "#B3B0B0",
}

plt.rcParams["text.color"] = text_color
plt.rcParams["font.family"] = "monospace"

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
from plottable import ColumnDefinition, Table
from plottable.plots import image
import matplotlib

from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.colors import LinearSegmentedColormap

from plottable import ColumnDefinition, Table
from plottable.plots import *

col_defs=[
    ColumnDefinition(
        name="Rk",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="Badge",
        textprops={"ha": "right", "va": "center", 'color': bg_color},
        width=0.5,
        plot_fn=image,
    ),
    ColumnDefinition(
        name="Squad",
        textprops={"ha": "left"},
        width=1.75,
    ),
    ColumnDefinition(
        name="MP",
        group="Matches Played",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="W",
        group="Matches Played",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="D",
        group="Matches Played",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="L",
        group="Matches Played",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="GF",
        group="Goals",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="GA",
        group="Goals",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="GD",
        group="Goals",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="Pts",
        group="Points",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="Pts/MP",
        group="Points",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="xG",
        group="Expected Goals",
        textprops={"ha": "center", "color": "#000000", "weight": "bold", "bbox": {"boxstyle": "circle", "pad": 0.35}},
        cmap=normed_cmap(df["xG"], cmap=matplotlib.cm.PiYG, num_stds=2)
    ),
    ColumnDefinition(
        name="xGA",
        group="Expected Goals",
        textprops={"ha": "center", "color": "#000000", "weight": "bold", "bbox": {"boxstyle": "circle", "pad": 0.35}},
        cmap=normed_cmap(df["xGA"], cmap=matplotlib.cm.PiYG_r, num_stds=2)
    ),
    ColumnDefinition(
        name="xGD",
        group="Expected Goals",
        textprops={"ha": "center", "color": "#000000", "weight": "bold", "bbox": {"boxstyle": "circle", "pad": 0.35}},
        cmap=normed_cmap(df["xGD"], cmap=matplotlib.cm.PiYG, num_stds=2)
    ),
    ColumnDefinition(
        name="xGD/90",
        textprops={"ha": "center", "color": "#000000", "weight": "bold", "bbox": {"boxstyle": "circle", "pad": 0.35}},
        cmap=normed_cmap(df["xGD/90"], cmap=matplotlib.cm.PiYG, num_stds=2)
    ),
    ColumnDefinition(
        name="Top Scorer Images",
        textprops={"ha":"center", 'color': bg_color},
        plot_fn=image,
        width=1.5,
    ),
    ColumnDefinition(
        name="Top Team Scorer",
        textprops={"ha":"center"},
        width=1.75,
),
]

# %%
from matplotlib.lines import Line2D
from PIL import Image
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

fig, ax = plt.subplots(figsize=(38, 40))
fig.set_facecolor(bg_color)
ax.set_facecolor(bg_color)
table = Table(
    df,
    column_definitions=col_defs,
    index_col="Rk",
    row_dividers=True,
    row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    footer_divider=True,
    textprops={"fontsize": 14},
    col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    column_border_kw={"linewidth": .5, "linestyle": "-"},
    ax=ax,
).autoset_fontcolors(colnames=["xG", "xGA", "xGD"])

#League badge
club_image=Image.open('/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Serie_A_ENILIVE_logo.png')
imagebox=OffsetImage(club_image, zoom=0.3)
ab=AnnotationBbox(imagebox, (0.03,1.01), frameon=True, xycoords='axes fraction')
ax.add_artist(ab)

#Add title at the top
fig.suptitle('2024-25 Serie A Stats', fontsize=28, color=text_color, weight='bold', y=0.9)

plt.savefig("/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Serie A 2024-25 Table.png",
    facecolor= ax.get_facecolor(),
    dpi=200,
    bbox_inches="tight",
)
fig.show()
# Out:
# /var/folders/tc/b844__mx5sl6dq_8zjb208yh0000gn/T/ipykernel_65449/3407946377.py:35: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
