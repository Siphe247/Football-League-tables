# %%
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt

from plottable import ColumnDefinition, Table
from plottable.cmap import normed_cmap
from plottable.plots import image

# %%
df=pd.read_html('https://fbref.com/en/comps/13/Ligue-1-Stats', attrs={"id":"results2024-2025131_overall"})[0]

# %%
df
# Out:
#     Rk          Squad  MP   W   D   L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0    1      Paris S-G  33  25   6   2  89  34  55   81    2.45  85.8  30.6
# 1    2      Marseille  33  19   5   9  70  45  25   62    1.88  59.8  44.0
# 2    3         Monaco  33  18   7   8  63  37  26   61    1.85  72.3  33.1
# 3    4           Nice  33  16   9   8  60  41  19   57    1.73  56.7  39.4
# 4    5          Lille  33  16   9   8  50  35  15   57    1.73  52.7  42.3
# 5    6     Strasbourg  33  16   9   8  54  41  13   57    1.73  47.7  53.6
# 6    7           Lyon  33  16   6  11  63  46  17   54    1.64  56.4  45.2
# 7    8          Brest  33  15   5  13  52  53  -1   50    1.52  44.5  52.5
# 8    9           Lens  33  14   7  12  38  39  -1   49    1.48  50.0  44.8
# 9   10        Auxerre  33  11   9  13  47  48  -1   42    1.27  40.4  55.5
# 10  11         Rennes  33  13   2  18  49  46   3   41    1.24  47.3  42.1
# 11  12       Toulouse  33  10   9  14  41  41   0   39    1.18  46.0  35.4
# 12  13         Angers  33  10   6  17  32  51 -19   36    1.09  35.6  53.9
# 13  14          Reims  33   8   9  16  32  45 -13   33    1.00  37.3  55.3
# 14  15         Nantes  33   7  12  14  36  52 -16   33    1.00  36.6  54.8
# 15  16       Le Havre  33   9   4  20  37  69 -32   31    0.94  38.9  61.3
# 16  17  Saint-Étienne  32   7   6  19  35  74 -39   27    0.84  35.0  71.1
# 17  18    Montpellier  32   4   4  24  23  74 -51   16    0.50  32.7  60.8
#
#      xGD  xGD/90     Last 5  Attendance  \
# 0   55.1    1.67  W D L L W       47225
# 1   15.9    0.48  L W W D W       63140
# 2   39.3    1.19  W D D W W        9435
# 3   17.4    0.53  D W W W L       24719
# 4   10.3    0.31  W W W D L       40888
# 5   -5.9   -0.18  D D W W L       19473
# 6   11.1    0.34  W L W L L       51215
# 7   -8.0   -0.24  D L L W W       14760
# 8    5.2    0.16  L W L W D       37936
# 9  -15.1   -0.46  L L W L D       16614
# 10   5.3    0.16  W W L L W       27361
# 11  10.5    0.32  L L D W D       24711
# 12 -18.3   -0.56  W L L W W       13267
# 13 -18.0   -0.55  W W D L L       15637
# 14 -18.1   -0.55  L D D L D       29627
# 15 -22.4   -0.68  L L D W L       20156
# 16 -36.1   -1.13  D W L L W       26437
# 17 -28.1   -0.88  L L D L L       13410
#
#                             Top Team Scorer            Goalkeeper  Notes
# 0                      Ousmane Dembélé - 21  Gianluigi Donnarumma    NaN
# 1                      Mason Greenwood - 19        Gerónimo Rulli    NaN
# 2                         Mika Biereth - 13          Philipp Köhn    NaN
# 3                       Evann Guessand - 11          Marcin Bułka    NaN
# 4                       Jonathan David - 16       Lucas Chevalier    NaN
# 5                       Emanuel Emegha - 14        Đorđe Petrović    NaN
# 6                  Alexandre Lacazette - 13           Lucas Perri    NaN
# 7                      Ludovic Ajorque - 13           Marco Bizot    NaN
# 8         M'Bala Nzola, Neil El Aynaoui - 6           Brice Samba    NaN
# 9   Gaëtan Perrin, Hamed Junior Traorè - 10          Donovan Léon    NaN
# 10                   Arnaud Kalimuendo - 17        Steve Mandanda    NaN
# 11                    Zakaria Aboukhlal - 7      Guillaume Restes    NaN
# 12                       Esteban Lepaul - 9          Yahia Fofana    NaN
# 13                      Keito Nakamura - 11         Yehvann Diouf    NaN
# 14                       Matthis Abline - 8         Anthony Lopes    NaN
# 15                      Abdoulaye Touré - 8         Arthur Desmas    NaN
# 16                       Lucas Stassin - 10    Gautier Larsonneur    NaN
# 17                        Arnaud Nordin - 4      Benjamin Lecomte    NaN

# %%
df['Badge']=df['Squad'].apply(
    lambda x: f"/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Ligue 1 Team Logos/{x.lower().replace('é','e')}_logo.png"
)

# %%
df['Badge'].tolist()
# Out:
# ['/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Ligue 1 Team Logos/paris s-g_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Ligue 1 Team Logos/marseille_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Ligue 1 Team Logos/monaco_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Ligue 1 Team Logos/nice_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Ligue 1 Team Logos/lille_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Ligue 1 Team Logos/strasbourg_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Ligue 1 Team Logos/lyon_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Ligue 1 Team Logos/brest_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Ligue 1 Team Logos/lens_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Ligue 1 Team Logos/auxerre_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Ligue 1 Team Logos/rennes_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Ligue 1 Team Logos/toulouse_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Ligue 1 Team Logos/angers_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Ligue 1 Team Logos/reims_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Ligue 1 Team Logos/nantes_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Ligue 1 Team Logos/le havre_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Ligue 1 Team Logos/saint-etienne_logo.png',
#  '/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Ligue 1 Team Logos/montpellier_logo.png']

# %%
df.columns
# Out:
# Index(['Rk', 'Squad', 'MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Pts/MP',
#        'xG', 'xGA', 'xGD', 'xGD/90', 'Last 5', 'Attendance', 'Top Team Scorer',
#        'Goalkeeper', 'Notes', 'Badge'],
#       dtype='object')

# %%
#Some data cleaning
df=df[['Rk','Badge','Squad','MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Pts/MP',
       'xG', 'xGA', 'xGD', 'xGD/90']]

# %%
df
# Out:
#     Rk                                              Badge          Squad  MP  \
# 0    1  /Users/siphuvuyomngxunyeni/Downloads/Football ...      Paris S-G  33
# 1    2  /Users/siphuvuyomngxunyeni/Downloads/Football ...      Marseille  33
# 2    3  /Users/siphuvuyomngxunyeni/Downloads/Football ...         Monaco  33
# 3    4  /Users/siphuvuyomngxunyeni/Downloads/Football ...           Nice  33
# 4    5  /Users/siphuvuyomngxunyeni/Downloads/Football ...          Lille  33
# 5    6  /Users/siphuvuyomngxunyeni/Downloads/Football ...     Strasbourg  33
# 6    7  /Users/siphuvuyomngxunyeni/Downloads/Football ...           Lyon  33
# 7    8  /Users/siphuvuyomngxunyeni/Downloads/Football ...          Brest  33
# 8    9  /Users/siphuvuyomngxunyeni/Downloads/Football ...           Lens  33
# 9   10  /Users/siphuvuyomngxunyeni/Downloads/Football ...        Auxerre  33
# 10  11  /Users/siphuvuyomngxunyeni/Downloads/Football ...         Rennes  33
# 11  12  /Users/siphuvuyomngxunyeni/Downloads/Football ...       Toulouse  33
# 12  13  /Users/siphuvuyomngxunyeni/Downloads/Football ...         Angers  33
# 13  14  /Users/siphuvuyomngxunyeni/Downloads/Football ...          Reims  33
# 14  15  /Users/siphuvuyomngxunyeni/Downloads/Football ...         Nantes  33
# 15  16  /Users/siphuvuyomngxunyeni/Downloads/Football ...       Le Havre  33
# 16  17  /Users/siphuvuyomngxunyeni/Downloads/Football ...  Saint-Étienne  32
# 17  18  /Users/siphuvuyomngxunyeni/Downloads/Football ...    Montpellier  32
#
#      W   D   L  GF  GA  GD  Pts  Pts/MP    xG   xGA   xGD  xGD/90
# 0   25   6   2  89  34  55   81    2.45  85.8  30.6  55.1    1.67
# 1   19   5   9  70  45  25   62    1.88  59.8  44.0  15.9    0.48
# 2   18   7   8  63  37  26   61    1.85  72.3  33.1  39.3    1.19
# 3   16   9   8  60  41  19   57    1.73  56.7  39.4  17.4    0.53
# 4   16   9   8  50  35  15   57    1.73  52.7  42.3  10.3    0.31
# 5   16   9   8  54  41  13   57    1.73  47.7  53.6  -5.9   -0.18
# 6   16   6  11  63  46  17   54    1.64  56.4  45.2  11.1    0.34
# 7   15   5  13  52  53  -1   50    1.52  44.5  52.5  -8.0   -0.24
# 8   14   7  12  38  39  -1   49    1.48  50.0  44.8   5.2    0.16
# 9   11   9  13  47  48  -1   42    1.27  40.4  55.5 -15.1   -0.46
# 10  13   2  18  49  46   3   41    1.24  47.3  42.1   5.3    0.16
# 11  10   9  14  41  41   0   39    1.18  46.0  35.4  10.5    0.32
# 12  10   6  17  32  51 -19   36    1.09  35.6  53.9 -18.3   -0.56
# 13   8   9  16  32  45 -13   33    1.00  37.3  55.3 -18.0   -0.55
# 14   7  12  14  36  52 -16   33    1.00  36.6  54.8 -18.1   -0.55
# 15   9   4  20  37  69 -32   31    0.94  38.9  61.3 -22.4   -0.68
# 16   7   6  19  35  74 -39   27    0.84  35.0  71.1 -36.1   -1.13
# 17   4   4  24  23  74 -51   16    0.50  32.7  60.8 -28.1   -0.88

# %%
# Set up the colors
# Used Coolors to get the color hex codes: https://coolors.co/?ref=65623355a0453d000b8a2708
bg_color = "#FFFFFF" # I usually just like to do a white background
text_color = "#000000" # With black text

row_colors = {
"even": "#E2E2E1",
"odd": "#B3B0B0",
}

plt.rcParams["text.color"] = text_color
plt.rcParams["font.family"] = "monospace"

# %%
col_defs=[
    ColumnDefinition(
        name="Rk",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="Badge",
        textprops={"ha": "right", "va": "center", 'color': bg_color},
        width=0.5,
        plot_fn=image,
    ),
    ColumnDefinition(
        name="Squad",
        textprops={"ha": "left"},
        width=1.75,
    ),
    ColumnDefinition(
        name="MP",
        group="Matches Played",
        textprops={"ha": "center", "weight": "bold"},
        width=0.5,
    ),
    ColumnDefinition(
        name="W",
        group="Matches Played",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="D",
        group="Matches Played",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="L",
        group="Matches Played",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="GF",
        group="Goals",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="GA",
        group="Goals",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="GD",
        group="Goals",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="Pts",
        group="Points",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="Pts/MP",
        group="Points",
        textprops={"ha": "center"},
        width=0.5,
    ),
    ColumnDefinition(
        name="xG",
        group="Expected Goals",
        textprops={"ha": "center", "color": "#000000", "weight": "bold", "bbox": {"boxstyle": "circle", "pad": 0.35}},
        cmap=normed_cmap(df["xG"], cmap=matplotlib.cm.PiYG, num_stds=2)
    ),
    ColumnDefinition(
        name="xGA",
        group="Expected Goals",
        textprops={"ha": "center", "color": "#000000", "weight": "bold", "bbox": {"boxstyle": "circle", "pad": 0.35}},
        cmap=normed_cmap(df["xGA"], cmap=matplotlib.cm.PiYG_r, num_stds=2)
    ),
    ColumnDefinition(
        name="xGD",
        group="Expected Goals",
        textprops={"ha": "center", "color": "#000000", "weight": "bold", "bbox": {"boxstyle": "circle", "pad": 0.35}},
        cmap=normed_cmap(df["xGD"], cmap=matplotlib.cm.PiYG, num_stds=2)
    ),
    ColumnDefinition(
        name="xGD/90",
        textprops={"ha": "center", "color": "#000000", "weight": "bold", "bbox": {"boxstyle": "circle", "pad": 0.35}},
        cmap=normed_cmap(df["xGD/90"], cmap=matplotlib.cm.PiYG, num_stds=2)
),
    ColumnDefinition(
        name="Top Scorer Image",
        textprops={"ha":"center", 'color': bg_color},
        plot_fn=image,
        width=0.75,
),
    ColumnDefinition(
        name="Top Team Scorer",
        textprops={"ha":"center"},
        width=1.75,
),
]

# %%
from matplotlib.lines import Line2D
from PIL import Image
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

fig, ax = plt.subplots(figsize=(20, 22))
fig.set_facecolor(bg_color)
ax.set_facecolor(bg_color)
table = Table(
    df,
    column_definitions=col_defs,
    index_col="Rk",
    row_dividers=True,
    row_divider_kw={"linewidth": 1, "linestyle": (0, (1, 5))},
    footer_divider=True,
    textprops={"fontsize": 14},
    col_label_divider_kw={"linewidth": 1, "linestyle": "-"},
    column_border_kw={"linewidth": .5, "linestyle": "-"},
    ax=ax,
).autoset_fontcolors(colnames=["xG", "xGA", "xGD"])

#League badge
club_image=Image.open('/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Ligue 1.png')
imagebox=OffsetImage(club_image, zoom=0.1)
ab=AnnotationBbox(imagebox, (0.12,0.99), frameon=True, xycoords='axes fraction')
ax.add_artist(ab)

#Add title at the top
fig.suptitle('2024-25 Ligue 1 Stats', fontsize=28, color=text_color, weight='bold', y=0.9)

plt.savefig("/Users/siphuvuyomngxunyeni/Downloads/Football Analytics/Ligue 1 2024-25 Table.png",
    facecolor= ax.get_facecolor(),
    dpi=200,
    bbox_inches="tight",
)
fig.show()
# Out:
# /var/folders/tc/b844__mx5sl6dq_8zjb208yh0000gn/T/ipykernel_50998/2258975254.py:35: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
